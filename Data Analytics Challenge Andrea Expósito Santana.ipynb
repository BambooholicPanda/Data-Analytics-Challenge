# %% [markdown]
# # Data Analytics - Challenge

# %% [markdown]
# The goal of this challenge is to analyze a restaurant invoices. Some celles are already implemented, you just need to **run** them. Some other cells need you to write some code.
#
# Start the challenge by running the two following cells:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %% [markdown]
# ---
#
# ❓ Display the 10 first rows of the dataset (no need to sort)
#
# <details>
#     <summary>🙈 Reveal solution</summary>
#
# <p>
# You can use the <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html"><code>pandas.DataFrame.head()</code></a> function:
#
# <pre>
# tips_df.head(10)
# </pre>
# </p>
# </details>

# %%
tips_df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# ---
#
# ❓ How many days per week is the restaurant open?
#
# <details>
#     <summary>🙈 Reveal solution</summary>
#
# <p>
# You can use the <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html"><code>pandas.Series.unique()</code></a> function combiend with the <code>len()</code> Python built-in.
#
# <pre>
# len(tips_df['day'].unique())
# </pre>
# </p>
# </details>

# %%
tips_df["day"].unique()
# set(tips_df["day"]) would also work
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# ---
#
# ❓ What day of the week is there more bills? Plot this with a Seaborn Countplot.
#
# <details>
#     <summary>🙈 Reveal solution</summary>
#
# <p>
# <pre>
# tips_df['day'].value_counts()
# </pre>
#
# <pre>
# sns.countplot(data=tips_df, x='day', order=['Thur', 'Fri', 'Sat', 'Sun'])
# </pre>
# </p>
# </details>

# %%
tips_df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips_df['day'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
#
# ❓ Try to do some other countplots, varying `x` with one of the categorical column (`sex`, `smoker`, `time`)

# %%
tips_df['smoker'].value_counts().plot(kind='bar')
# To add a cell, you can go in the menu and do Insert > Insert cell below
# Out:
# <AxesSubplot:>

# %%
tips_df['sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
tips_df['time'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
tips_df['size'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ❓ Let's plot the distribution of `total_bill` based on a given category. Start with `day`:
#
# ```python
# sns.catplot(data=tips_df, x='day', y='total_bill', kind="box")
# ```
#
# 1. Change the value of `x` with one of the categorical column of the dataset and the value of `kind` (`"bar"`, `"box"`, `"violin"`, `"boxen"`)
# 1. Change the value of `y` with one of the numerical column of the dataset

# %%
# Your experiments here

sns.catplot(data=tips_df, x='day', y='total_bill', kind="box")

# %%
sns.catplot(data=tips_df, x='sex', y='total_bill', kind="violin")

# %%
sns.catplot(data=tips_df, x='tip', y='total_bill', kind="boxen")

# %%
sns.catplot(data=tips_df, x='tip', y='day', kind="bar")

# %%
sns.catplot(data=tips_df, x='day', y='size', kind="box")

# %% [markdown]
# ---
# ❓ Let's use [`seaborn.FacetGrid`](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html)
#
# 1. Run the cell below. What do you observe?
# 2. Change `col` in the first line with another column (e.g. `"time"`). Run the cell again. What do you observe?

# %%
g = sns.FacetGrid(tips_df, col="day")
g.map(plt.hist, "total_bill")

# %% [raw]
# # I observe 4 bar charts that display the number of total bills in relation to how frequently in that day (Sunday, Saturday, Thursday or Friday) that peak of total bills has been reached. == Shows FREQUENCY
# For example, we can see that:
# a) on a Friday, reaching 50 total bills has a 0 frequency.
# b) on a Sunday, reaching ~19 total bills has a ~17 frequency.
# c) The frequency of reaching 20 total bills is the highest on a Saturday out of all days

# %%
g = sns.FacetGrid(tips_df, col="time")
g.map(plt.hist, "total_bill")

# %% [raw]
# # I observe 2 bar charts that display the number of total bills in relation to how frequently in that eating time (Dinner, Lunch) that peak of total bills has been reached. == Shows FREQUENCY
# For example, we can see that:
# a) A number of 10 total bills has a ~24 frecuency for Dinner time.
# b) A number of 50 total bills has a 0 frequency for Lunch time.
# c) A number of 50 total bills has a ~5 frequency for Dinner time.
# d) The total bills frequencies for Dinner time are all higher than those of Lunch time

# %%
g = sns.FacetGrid(tips_df, col="smoker")
g.map(plt.hist, "size")

# %% [raw]
# This is my own experiment. I wanted a chart that would show me the frequency of people that choose a table for smokers in relation to the number of people within the group (size).
# For example, we can see that:
# a) A group of 6 people choosing a table for smokers has a 0 frequency
# b) A group of 3 people is more likely to choose a table for non smokers than a table for smokers
# c) The group size that is more likely to choose a table for smokers is 2 people

# %% [markdown]
# ---
# ❓ Let's continue with FacetGrid and add a `row="smoker"` parameter. How many cells do you get in the plot?
#
# <details>
#     <summary>🙈 Reveal solution</summary>
#
# You get 2 * 4 = 8 cells!
#
# <pre>
# g = sns.FacetGrid(tips_df, col="day", row="smoker")
# g.map(plt.hist, "total_bill")
# </pre>
# </p>
# </details>

# %%
g = sns.FacetGrid(tips_df, col="day", row="smoker")
g.map(plt.hist, "total_bill")

# %% [raw]
# In this plot we get 8 cells. We can observe the frequency of the amount of total bills for each day (Sunday, Saturday, Thursday, Friday) in relation to the characteristic of being smoker or non smoker.
#
# This allows us to see that:
# a) If the restaurant hits a number of 40 total bills on a Sunday, the bills are more likely to be those of smokers than those of non smokers. (Actually 40 total bills - Sunday - no smoker has a frequency of 0, but we never know).
# b) The correlation of smokers and non smokers is more balanced on Saturdays out of all days (Sunday, Thursday and Friday exhibit very disctinct values on the comparison of smokers and non smokers, but the balance on Saturday is quite smooth, though it is not an exact 50-50 relation).
# c) Very similarly, we can visually interpret that on Friday there is a high imbalance in between the values of smokers and non smokers, and we can understand that Friday is the day with the least non smoker total bills. (I am aware that total bills represent a bill, not a number of people. 1 total bill could represent 1 person and a group of 6 people. And a smoker total bill could include a group of 4 people (size) but only 1 is a smoker and the other 3 are not, but they all sit in the smoker's area).
#
# As general conclusions, I would dare to say:
# - No smokers are more likely to go to the restaurant (except for Fridays)
# - Saturdays are the days that show more smoker-non smoker balance.

# %% [markdown]
# ## Correlation
#
# Let's start looking for correlation between columns in the dataset.

# %% [markdown]
# ---
# ❓ What is your intuition about the relationship between the columns `tip` and `total_bill`?

# %% [raw]
# My intuition tells me that the relation between both columns is the percentage of tip per bill. At first sight, I would say it is around 20%. This means that 20% per bill is the tip.

# %% [markdown]
# ---
# ❓ Let's look at the data to see if our intuition is correct. We will do a **scatterplot** with `x` being `total_bill` and `y` the tip.

# %%
with sns.axes_style(style="whitegrid"):
    sns.relplot(x="total_bill", y="tip", data=tips_df)

# %% [markdown]
# ---
# ❓ Another way of looking at this data is to use a [`seaborn.jointplot`](https://seaborn.pydata.org/generated/seaborn.jointplot.html).

# %%
with sns.axes_style("white"):
    sns.jointplot(x="total_bill", y="tip", kind="hex", data=tips_df)

# %% [markdown]
# ❓ A very useful tool to **identify** correlations is the [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html):

# %%
sns.pairplot(tips_df, height=2, hue="smoker")

# %% [markdown]
# ## Regression
#
# We are not doing Machine Learning yet but we can use [`seaborn.lmplot`](https://seaborn.pydata.org/generated/seaborn.lmplot.html) to graphically read a linear correlation between two columns:

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips_df)

# %% [markdown]
# ## Good job!
#
# Save your notebook, go back to the **Le Wagon - Learn** platform to upload your progress. A quiz awaits you!
